# %% [markdown]
# # PySpark inner join and broadcast join
#
# ## Source data
#
# The source comes from jupyter-pyspark/f1-sourcefiles
#
# # Inner the data from the results.csv and races.csv

# %% [markdown]
# # Initalise a spark session

# %%
# Initalise a spark session
import os
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip
from pyspark.sql.functions import col

# Fix JAVA_HOME to your actual Java 21 path
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-21-openjdk-amd64"
os.environ["PYSPARK_SUBMIT_ARGS"] = "--packages io.delta:delta-spark_2.12:3.2.0 pyspark-shell"

# Build Spark session with Delta Lake support
builder = SparkSession.builder \
    .appName("DeltaLakeExample") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()
# Out:
# 26/04/27 21:49:45 WARN Utils: Your hostname, DESKTOP-OQT8U26 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/27 21:49:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/robyip/projects/pyspark-deltalake/.venv/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/robyip/.ivy2/cache
# The jars for the packages stored in: /home/robyip/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-9b5875a4-4019-4e65-9c28-d5cca6db7127;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.2.0 in central
# 	found io.delta#delta-storage;3.2.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 177ms :: artifacts dl 9ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.2.0 from central in [default]
# 	io.delta#delta-storage;3.2.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-9b5875a4-4019-4e65-9c28-d5cca6db7127
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/8ms)
# 26/04/27 21:49:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# # Load results.csv and races.csv into dataframes

# %%
# Load csv files into dataframes
#  Contains headers
# Infers schema

results = spark.read.csv("f1-sourcefiles/results.csv", header=True, inferSchema=True)

races = spark.read.csv("f1-sourcefiles/races.csv", header=True, inferSchema=True)
# Out:
# 26/04/27 21:49:59 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %% [markdown]
# # Show the data type of the dataframes

# %%
# results 

results.printSchema()

# races

races.printSchema()
# Out:
# root
#  |-- resultId: integer (nullable = true)
#  |-- raceId: integer (nullable = true)
#  |-- driverId: integer (nullable = true)
#  |-- constructorId: integer (nullable = true)
#  |-- number: string (nullable = true)
#  |-- grid: integer (nullable = true)
#  |-- position: string (nullable = true)
#  |-- positionText: string (nullable = true)
#  |-- positionOrder: integer (nullable = true)
#  |-- points: double (nullable = true)
#  |-- laps: integer (nullable = true)
#  |-- time: string (nullable = true)
#  |-- milliseconds: string (nullable = true)
#  |-- fastestLap: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- fastestLapTime: string (nullable = true)
#  |-- fastestLapSpeed: string (nullable = true)
#  |-- statusId: integer (nullable = true)
#
# root
#  |-- raceId: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- round: integer (nullable = true)
#  |-- circuitId: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- fp1_date: string (nullable = true)
#  |-- fp1_time: string (nullable = true)
#  |-- fp2_date: string (nullable = true)
#  |-- fp2_time: string (nullable = true)
#  |-- fp3_date: string (nullable = true)
#  |-- fp3_time: string (nullable = true)
#  |-- quali_date: string (nullable = true)
#  |-- quali_time: string (nullable = true)
#  |-- sprint_date: string (nullable = true)
#  |-- sprint_time: string (nullable = true)

# %% [markdown]
# # Use Alias in an INNER JOIN

# %%
# Inner join on same column name i.e. raceid


# Create and alias for a Dataframe just like tabel alias in SQL

results = results.alias("rslt")

races = races.alias("rcs")

# join on raceid and look at shuffle size to optimise on?


joined_df = results.join(races, col("rslt.raceId") == col("rcs.raceId"), how="inner") \
    .filter("rcs.year == 2024") \
    .select(col("rslt.resultId"), col("rcs.raceId"), col("rcs.year"), col("rcs.round"), col("rcs.name").alias("race_name"))

joined_df.explain()

joined_df.show()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [resultId#17, raceId#70, year#71, round#72, name#74 AS race_name#180]
#    +- BroadcastHashJoin [raceId#18], [raceId#70], Inner, BuildRight, false
#       :- Filter isnotnull(raceId#18)
#       :  +- FileScan csv [resultId#17,raceId#18] Batched: false, DataFilters: [isnotnull(raceId#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-source..., PartitionFilters: [], PushedFilters: [IsNotNull(raceId)], ReadSchema: struct<resultId:int,raceId:int>
#       +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=64]
#          +- Filter ((isnotnull(year#71) AND (year#71 = 2024)) AND isnotnull(raceId#70))
#             +- FileScan csv [raceId#70,year#71,round#72,name#74] Batched: false, DataFilters: [isnotnull(year#71), (year#71 = 2024), isnotnull(raceId#70)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-source..., PartitionFilters: [], PushedFilters: [IsNotNull(year), EqualTo(year,2024), IsNotNull(raceId)], ReadSchema: struct<raceId:int,year:int,round:int,name:string>
#
#
# +--------+------+----+-----+------------------+
# |resultId|raceId|year|round|         race_name|
# +--------+------+----+-----+------------------+
# |   26286|  1121|2024|    1|Bahrain Grand Prix|
# |   26287|  1121|2024|    1|Bahrain Grand Prix|
# |   26288|  1121|2024|    1|Bahrain Grand Prix|
# |   26289|  1121|2024|    1|Bahrain Grand Prix|
# |   26290|  1121|2024|    1|Bahrain Grand Prix|
# |   26291|  1121|2024|    1|Bahrain Grand Prix|
# |   26292|  1121|2024|    1|Bahrain Grand Prix|
# |   26293|  1121|2024|    1|Bahrain Grand Prix|
# |   26294|  1121|2024|    1|Bahrain Grand Prix|
# |   26295|  1121|2024|    1|Bahrain Grand Prix|
# |   26296|  1121|2024|    1|Bahrain Grand Prix|
# |   26297|  1121|2024|    1|Bahrain Grand Prix|
# |   26298|  1121|2024|    1|Bahrain Grand Prix|
# |   26299|  1121|2024|    1|Bahrain Grand Prix|
# |   26300|  1121|2024|    1|Bahrain Grand Prix|
# |   26301|  1121|2024|    1|Bahrain Grand Prix|
# |   26302|  1121|2024|    1|Bahrain Grand Prix|
# |   26303|  1121|2024|    1|Bahrain Grand Prix|
# |   26304|  1121|2024|    1|Bahrain Grand Prix|
# |   26305|  1121|2024|    1|Bahrain Grand Prix|
# +--------+------+----+-----+------------------+
# only showing top 20 rows

# %% [markdown]
# # Force a broadcast hash join INNER JOIN

# %%
# Inner join on same column name i.e. raceid

from pyspark.sql.functions import broadcast

# Create and alias for a Dataframe just like tabel alias in SQL

results = results.alias("rslt")

races = races.alias("rcs")

# join on raceid and look at shuffle size to optimise on?

# Force a broadcast join
joined_df = results.join(broadcast(races), col("rslt.raceId") == col("rcs.raceId"), how="inner") \
    .filter("rcs.year == 2024") \
    .select(col("rslt.resultId"), col("rcs.raceId"), col("rcs.year"), col("rcs.round"), col("rcs.name").alias("race_name"))

joined_df.explain(mode="formatted")

joined_df.show()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (8)
# +- Project (7)
#    +- BroadcastHashJoin Inner BuildRight (6)
#       :- Filter (2)
#       :  +- Scan csv  (1)
#       +- BroadcastExchange (5)
#          +- Filter (4)
#             +- Scan csv  (3)
#
#
# (1) Scan csv
# Output [2]: [resultId#17, raceId#18]
# Batched: false
# Location: InMemoryFileIndex [file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-sourcefiles/results.csv]
# PushedFilters: [IsNotNull(raceId)]
# ReadSchema: struct<resultId:int,raceId:int>
#
# (2) Filter
# Input [2]: [resultId#17, raceId#18]
# Condition : isnotnull(raceId#18)
#
# (3) Scan csv
# Output [4]: [raceId#70, year#71, round#72, name#74]
# Batched: false
# Location: InMemoryFileIndex [file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-sourcefiles/races.csv]
# PushedFilters: [IsNotNull(year), EqualTo(year,2024), IsNotNull(raceId)]
# ReadSchema: struct<raceId:int,year:int,round:int,name:string>
#
# (4) Filter
# Input [4]: [raceId#70, year#71, round#72, name#74]
# Condition : ((isnotnull(year#71) AND (year#71 = 2024)) AND isnotnull(raceId#70))
#
# (5) BroadcastExchange
# Input [4]: [raceId#70, year#71, round#72, name#74]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=450]
#
# (6) BroadcastHashJoin
# Left keys [1]: [raceId#18]
# Right keys [1]: [raceId#70]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [5]: [resultId#17, raceId#70, year#71, round#72, name#74 AS race_name#858]
# Input [6]: [resultId#17, raceId#18, raceId#70, year#71, round#72, name#74]
#
# (8) AdaptiveSparkPlan
# Output [5]: [resultId#17, raceId#70, year#71, round#72, race_name#858]
# Arguments: isFinalPlan=false
#
#
# +--------+------+----+-----+------------------+
# |resultId|raceId|year|round|         race_name|
# +--------+------+----+-----+------------------+
# |   26286|  1121|2024|    1|Bahrain Grand Prix|
# |   26287|  1121|2024|    1|Bahrain Grand Prix|
# |   26288|  1121|2024|    1|Bahrain Grand Prix|
# |   26289|  1121|2024|    1|Bahrain Grand Prix|
# |   26290|  1121|2024|    1|Bahrain Grand Prix|
# |   26291|  1121|2024|    1|Bahrain Grand Prix|
# |   26292|  1121|2024|    1|Bahrain Grand Prix|
# |   26293|  1121|2024|    1|Bahrain Grand Prix|
# |   26294|  1121|2024|    1|Bahrain Grand Prix|
# |   26295|  1121|2024|    1|Bahrain Grand Prix|
# |   26296|  1121|2024|    1|Bahrain Grand Prix|
# |   26297|  1121|2024|    1|Bahrain Grand Prix|
# |   26298|  1121|2024|    1|Bahrain Grand Prix|
# |   26299|  1121|2024|    1|Bahrain Grand Prix|
# |   26300|  1121|2024|    1|Bahrain Grand Prix|
# |   26301|  1121|2024|    1|Bahrain Grand Prix|
# |   26302|  1121|2024|    1|Bahrain Grand Prix|
# |   26303|  1121|2024|    1|Bahrain Grand Prix|
# |   26304|  1121|2024|    1|Bahrain Grand Prix|
# |   26305|  1121|2024|    1|Bahrain Grand Prix|
# +--------+------+----+-----+------------------+
# only showing top 20 rows

# %% [markdown]
# # This is a sample showing a broadcast join is used.
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [resultId#17, raceId#70, year#71, round#72, name#74 AS race_name#285]
#    +- BroadcastHashJoin [raceId#18], [raceId#70], Inner, BuildRight, false
#       :- Filter isnotnull(raceId#18)

# %% [markdown]
# # How to get the current broadcast  threshold

# %%
# Safe way — use SparkContext's byteString parser
threshold_bytes = spark._jvm.org.apache.spark.network.util.JavaUtils.byteStringAsBytes(
    spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
)
print(f"Broadcast threshold: {threshold_bytes / (1024 * 1024):.1f} MB")
# Out:
# Broadcast threshold: 10.0 MB

# %% [markdown]
# # Disable broadcast join

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)

# %% [markdown]
# # This join I have removed the broadcast function in the join so I can see if the disabled worked

# %%
# Inner join on same column name i.e. raceid

from pyspark.sql.functions import broadcast

# Create and alias for a Dataframe just like tabel alias in SQL

results = results.alias("rslt")

races = races.alias("rcs")

# join on raceid and look at shuffle size to optimise on?

# Force a broadcast join
joined_df = results.join(races, col("rslt.raceId") == col("rcs.raceId"), how="inner") \
    .filter("rcs.year == 2024") \
    .select(col("rslt.resultId"), col("rcs.raceId"), col("rcs.year"), col("rcs.round"), col("rcs.name").alias("race_name"))

joined_df.explain(mode="formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (11)
# +- Project (10)
#    +- SortMergeJoin Inner (9)
#       :- Sort (4)
#       :  +- Exchange (3)
#       :     +- Filter (2)
#       :        +- Scan csv  (1)
#       +- Sort (8)
#          +- Exchange (7)
#             +- Filter (6)
#                +- Scan csv  (5)
#
#
# (1) Scan csv
# Output [2]: [resultId#17, raceId#18]
# Batched: false
# Location: InMemoryFileIndex [file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-sourcefiles/results.csv]
# PushedFilters: [IsNotNull(raceId)]
# ReadSchema: struct<resultId:int,raceId:int>
#
# (2) Filter
# Input [2]: [resultId#17, raceId#18]
# Condition : isnotnull(raceId#18)
#
# (3) Exchange
# Input [2]: [resultId#17, raceId#18]
# Arguments: hashpartitioning(raceId#18, 200), ENSURE_REQUIREMENTS, [plan_id=418]
#
# (4) Sort
# Input [2]: [resultId#17, raceId#18]
# Arguments: [raceId#18 ASC NULLS FIRST], false, 0
#
# (5) Scan csv
# Output [4]: [raceId#70, year#71, round#72, name#74]
# Batched: false
# Location: InMemoryFileIndex [file:/home/robyip/projects/pyspark-deltalake/jupyter-pyspark/f1-sourcefiles/races.csv]
# PushedFilters: [IsNotNull(year), EqualTo(year,2024), IsNotNull(raceId)]
# ReadSchema: struct<raceId:int,year:int,round:int,name:string>
#
# (6) Filter
# Input [4]: [raceId#70, year#71, round#72, name#74]
# Condition : ((isnotnull(year#71) AND (year#71 = 2024)) AND isnotnull(raceId#70))
#
# (7) Exchange
# Input [4]: [raceId#70, year#71, round#72, name#74]
# Arguments: hashpartitioning(raceId#70, 200), ENSURE_REQUIREMENTS, [plan_id=419]
#
# (8) Sort
# Input [4]: [raceId#70, year#71, round#72, name#74]
# Arguments: [raceId#70 ASC NULLS FIRST], false, 0
#
# (9) SortMergeJoin
# Left keys [1]: [raceId#18]
# Right keys [1]: [raceId#70]
# Join type: Inner
# Join condition: None
#
# (10) Project
# Output [5]: [resultId#17, raceId#70, year#71, round#72, name#74 AS race_name#780]
# Input [6]: [resultId#17, raceId#18, raceId#70, year#71, round#72, name#74]
#
# (11) AdaptiveSparkPlan
# Output [5]: [resultId#17, raceId#70, year#71, round#72, race_name#780]
# Arguments: isFinalPlan=false

# %% [markdown]
# # Reset the broadcast threshold
# Use this to re-enable broadcasting threshold so we can see a broadcast join is used.

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 10 * 1024 * 1024)
